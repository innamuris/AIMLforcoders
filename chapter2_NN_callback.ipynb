# %%
# NN training using callback - which means stopping training

# %%
import tensorflow as tf

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.95):
      print("\nReached 95% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = myCallback()
mnist = tf.keras.datasets.fashion_mnist

(training_images, training_labels),(test_images, test_labels) = mnist.load_data()

training_images=training_images/255.0
test_images=test_images/255.0

model = tf.keras.models.Sequential([
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation=tf.nn.relu),
        tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(optimizer='adam', 
               loss='sparse_categorical_crossentropy', 
               metrics=['accuracy'])

model.fit(training_images, training_labels, epochs=50, 
           callbacks=[callbacks])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4992 - accuracy: 0.8238
# dict_keys(['loss', 'accuracy'])
# Epoch 2/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3759 - accuracy: 0.8647
# dict_keys(['loss', 'accuracy'])
# Epoch 3/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3386 - accuracy: 0.8753
# dict_keys(['loss', 'accuracy'])
# Epoch 4/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3152 - accuracy: 0.8841
# dict_keys(['loss', 'accuracy'])
# Epoch 5/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2952 - accuracy: 0.8918
# dict_keys(['loss', 'accuracy'])
# Epoch 6/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2798 - accuracy: 0.8965
# dict_keys(['loss', 'accuracy'])
# Epoch 7/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2689 - accuracy: 0.9002
# dict_keys(['loss', 'accuracy'])
# Epoch 8/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2577 - accuracy: 0.9039
# dict_keys(['loss', 'accuracy'])
# Epoch 9/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2477 - accuracy: 0.9084
# dict_keys(['loss', 'accuracy'])
# Epoch 10/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2386 - accuracy: 0.9113
# dict_keys(['loss', 'accuracy'])
# Epoch 11/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2328 - accuracy: 0.9135
# dict_keys(['loss', 'accuracy'])
# Epoch 12/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2249 - accuracy: 0.9160
# dict_keys(['loss', 'accuracy'])
# Epoch 13/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2152 - accuracy: 0.9206
# dict_keys(['loss', 'accuracy'])
# Epoch 14/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2109 - accuracy: 0.9212
# dict_keys(['loss', 'accuracy'])
# Epoch 15/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2030 - accuracy: 0.9245
# dict_keys(['loss', 'accuracy'])
# Epoch 16/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2002 - accuracy: 0.9252
# dict_keys(['loss', 'accuracy'])
# Epoch 17/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1934 - accuracy: 0.9272
# dict_keys(['loss', 'accuracy'])
# Epoch 18/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1885 - accuracy: 0.9298
# dict_keys(['loss', 'accuracy'])
# Epoch 19/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1840 - accuracy: 0.9305
# dict_keys(['loss', 'accuracy'])
# Epoch 20/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1785 - accuracy: 0.9337
# dict_keys(['loss', 'accuracy'])
# Epoch 21/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1736 - accuracy: 0.9353
# dict_keys(['loss', 'accuracy'])
# Epoch 22/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1699 - accuracy: 0.9362
# dict_keys(['loss', 'accuracy'])
# Epoch 23/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1669 - accuracy: 0.9368
# dict_keys(['loss', 'accuracy'])
# Epoch 24/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1607 - accuracy: 0.9397
# dict_keys(['loss', 'accuracy'])
# Epoch 25/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1585 - accuracy: 0.9400
# dict_keys(['loss', 'accuracy'])
# Epoch 26/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1553 - accuracy: 0.9411
# dict_keys(['loss', 'accuracy'])
# Epoch 27/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1525 - accuracy: 0.9428
# dict_keys(['loss', 'accuracy'])
# Epoch 28/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1490 - accuracy: 0.9434
# dict_keys(['loss', 'accuracy'])
# Epoch 29/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1456 - accuracy: 0.9454
# dict_keys(['loss', 'accuracy'])
# Epoch 30/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1400 - accuracy: 0.9463
# dict_keys(['loss', 'accuracy'])
# Epoch 31/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1383 - accuracy: 0.9478
# dict_keys(['loss', 'accuracy'])
# Epoch 32/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1348 - accuracy: 0.9492
# dict_keys(['loss', 'accuracy'])
# Epoch 33/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1328 - accuracy: 0.9507
# dict_keys(['loss', 'accuracy'])
#
# Reached 95% accuracy so cancelling training!
